# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 705us/step - loss: 0.6280 - accuracy: 0.6788
# Epoch 2/50
# 18/18 [==============================] - 0s 619us/step - loss: 0.6015 - accuracy: 0.7083
# Epoch 3/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5799 - accuracy: 0.7222
# Epoch 4/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5619 - accuracy: 0.7413
# Epoch 5/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5461 - accuracy: 0.7465
# Epoch 6/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5337 - accuracy: 0.7587
# Epoch 7/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5228 - accuracy: 0.7622
# Epoch 8/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5135 - accuracy: 0.7708
# Epoch 9/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5060 - accuracy: 0.7708
# Epoch 10/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4987 - accuracy: 0.7708
# Epoch 11/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4931 - accuracy: 0.7708
# Epoch 12/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4875 - accuracy: 0.7726
# Epoch 13/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4831 - accuracy: 0.7743
# Epoch 14/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4792 - accuracy: 0.7743
# Epoch 15/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4762 - accuracy: 0.7778
# Epoch 16/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4727 - accuracy: 0.7795
# Epoch 17/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4697 - accuracy: 0.7795
# Epoch 18/50
# 18/18 [==============================] - 0s 711us/step - loss: 0.4674 - accuracy: 0.7830
# Epoch 19/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4648 - accuracy: 0.7847
# Epoch 20/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4629 - accuracy: 0.7830
# Epoch 21/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4615 - accuracy: 0.7830
# Epoch 22/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4592 - accuracy: 0.7847
# Epoch 23/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4578 - accuracy: 0.7865
# Epoch 24/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4564 - accuracy: 0.7865
# Epoch 25/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4552 - accuracy: 0.7882
# Epoch 26/50
# 18/18 [==============================] - 0s 664us/step - loss: 0.4537 - accuracy: 0.7899
# Epoch 27/50
# 18/18 [==============================] - 0s 704us/step - loss: 0.4525 - accuracy: 0.7899
# Epoch 28/50
# 18/18 [==============================] - 0s 705us/step - loss: 0.4513 - accuracy: 0.7882
# Epoch 29/50
# 18/18 [==============================] - 0s 643us/step - loss: 0.4505 - accuracy: 0.7899
# Epoch 30/50
# 18/18 [==============================] - 0s 652us/step - loss: 0.4491 - accuracy: 0.7899
# Epoch 31/50
# 18/18 [==============================] - 0s 648us/step - loss: 0.4483 - accuracy: 0.7899
# Epoch 32/50
# 18/18 [==============================] - 0s 701us/step - loss: 0.4476 - accuracy: 0.7882
# Epoch 33/50
# 18/18 [==============================] - 0s 648us/step - loss: 0.4463 - accuracy: 0.7917
# Epoch 34/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4457 - accuracy: 0.7899
# Epoch 35/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4451 - accuracy: 0.7882
# Epoch 36/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4440 - accuracy: 0.7847
# Epoch 37/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4437 - accuracy: 0.7865
# Epoch 38/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4429 - accuracy: 0.7847
# Epoch 39/50
# 18/18 [==============================] - 0s 648us/step - loss: 0.4421 - accuracy: 0.7847
# Epoch 40/50
# 18/18 [==============================] - 0s 697us/step - loss: 0.4418 - accuracy: 0.7830
# Epoch 41/50
# 18/18 [==============================] - 0s 645us/step - loss: 0.4412 - accuracy: 0.7847
# Epoch 42/50
# 18/18 [==============================] - 0s 648us/step - loss: 0.4405 - accuracy: 0.7830
# Epoch 43/50
# 18/18 [==============================] - 0s 586us/step - loss: 0.4404 - accuracy: 0.7917
# Epoch 44/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4394 - accuracy: 0.7882
# Epoch 45/50
# 18/18 [==============================] - 0s 643us/step - loss: 0.4392 - accuracy: 0.7882
# Epoch 46/50
# 18/18 [==============================] - 0s 703us/step - loss: 0.4384 - accuracy: 0.7882
# Epoch 47/50
# 18/18 [==============================] - 0s 996us/step - loss: 0.4381 - accuracy: 0.7899
# Epoch 48/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4379 - accuracy: 0.7899
# Epoch 49/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4373 - accuracy: 0.7882
# Epoch 50/50
# 18/18 [==============================] - 0s 654us/step - loss: 0.4365 - accuracy: 0.7899
# 6/6 - 0s - loss: 0.4727 - accuracy: 0.7604 - 87ms/epoch - 14ms/step
# Loss: 0.47270265221595764, Accuracy: 0.7604166865348816
